# %%
#imports
import seaborn as sns 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

import pandas as pd

import torch
from torch import nn
from torch.utils.data import DataLoader
import torch.optim as optim 

from typing import Callable, Tuple

# %%
#load dataset
df = pd.read_csv("Salary_dataset.csv")

# %%
#explore/clean dataset
print(df.head())
sns.scatterplot(data=df, x="YearsExperience", y="Salary") #, hue="Unnamed: 0")
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
Y = df[["Salary"]]
X = df[["YearsExperience"]]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Use linear regression to model the salery-experience relation 

# Model Training
reg = LinearRegression()
reg.fit(X_train, Y_train)

# Model Predict
pred = reg.predict(X_test)

# Model Evaluation
mse = mean_squared_error(Y_test, pred)
print(mse)

# Print Line Equation (y = mx + b)
m = reg.coef_[0][0]
b = reg.intercept_[0]

X_range = np.linspace(1,11,100)

y_line = m*X_range + b

#plot reg line 
sns.set(style="darkgrid")
plt.figure(figsize=(10, 6))

sns.scatterplot(data=df, x="YearsExperience", y="Salary", label="Data Points", color='blue')
sns.lineplot(x=X_range, y=y_line, color="red", label="Regression Line")

plt.xlabel("Years of Experience")  # x-axis label
plt.ylabel("Salary in USD")  # y-axis label (customized)
# Plot title
plt.title("Salary vs Experience with Linear Regression Line")
# Show legend and plot
plt.legend()
plt.show()
# Out:
# 49830096.855908394
